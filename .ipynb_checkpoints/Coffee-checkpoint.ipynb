# %% [markdown]
# # Exploring the coffee production data set

# %% [markdown]
# Importing the packages I need

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
plt.rcParams['font.size'] = '15'

# %% [markdown]
# Importing the coffee production dataset

# %%
df = pd.read_csv('ICO_CROP_DATA.csv')

# %% [markdown]
# Now to do some EDA and checking for missing values

# %%
df.head(5)
# Out:
#    COUNTRY     YEAR  MONTH  TOTAL_PRODUCTION  DOMESTIC_CONSUMPTION  \
# 0   Angola  1990/91  April           50.3450                  20.0
# 1  Bolivia  1990/91  April          122.7770                  25.0
# 2   Brazil  1990/91  April        27285.6286                8200.0
# 3  Burundi  1990/91  April          487.3930                   2.0
# 4  Ecuador  1990/91  April         1503.8150                 350.0
#
#    EXPORTABLE_PRODUCTION  GROSS_OPENING_STOCKS
# 0                30.3450               210.000
# 1                97.7770                54.000
# 2             19085.6286             26926.000
# 3               485.3930                77.000
# 4              1153.8150               723.963

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1568 entries, 0 to 1567
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   COUNTRY                1568 non-null   object
#  1   YEAR                   1568 non-null   object
#  2   MONTH                  1568 non-null   object
#  3   TOTAL_PRODUCTION       1521 non-null   float64
#  4   DOMESTIC_CONSUMPTION   1521 non-null   float64
#  5   EXPORTABLE_PRODUCTION  1559 non-null   float64
#  6   GROSS_OPENING_STOCKS   1560 non-null   float64
# dtypes: float64(4), object(3)
# memory usage: 85.9+ KB

# %%
df.describe()
# Out:
#        TOTAL_PRODUCTION  DOMESTIC_CONSUMPTION  EXPORTABLE_PRODUCTION  \
# count       1521.000000           1521.000000            1559.000000
# mean        2244.821485            615.311021            1620.558960
# std         6230.405278           2159.586060            4302.678374
# min            0.000000              0.000000               0.000000
# 25%           44.313000              5.000000              10.628250
# 50%          370.612300             67.000000             135.000000
# 75%         1572.432600            330.000000            1247.014250
# max        56763.763400          21997.000000           35538.763400
#
#        GROSS_OPENING_STOCKS
# count           1560.000000
# mean             669.945847
# std             3505.872743
# min                0.000000
# 25%                0.000000
# 50%               17.645500
# 75%              153.321000
# max            43762.000000

# %% [markdown]
# Seems to only be a few missing values and so for ease I will drop them

# %%
df.dropna(inplace=True)

# %%
df.describe()
# Out:
#        TOTAL_PRODUCTION  DOMESTIC_CONSUMPTION  EXPORTABLE_PRODUCTION  \
# count       1516.000000           1516.000000            1516.000000
# mean        2252.220858            617.340411            1666.520291
# std         6239.342578           2162.857004            4354.521203
# min            0.000000              0.000000               0.000000
# 25%           44.719275              5.000000              15.080575
# 50%          373.893500             67.000000             159.022600
# 75%         1584.541750            330.000000            1331.352075
# max        56763.763400          21997.000000           35538.763400
#
#        GROSS_OPENING_STOCKS
# count           1516.000000
# mean             689.390186
# std             3554.532404
# min                0.000000
# 25%                0.000000
# 50%               20.000000
# 75%              161.000000
# max            43762.000000

# %% [markdown]
# The min value still appears to be zero, so it may infact be a true value

# %%
df[df.loc[:,'TOTAL_PRODUCTION'] == 0]
# Out:
#                 COUNTRY     YEAR    MONTH  TOTAL_PRODUCTION  \
# 21                Benin  1990/91  October               0.0
# 77                Benin  1991/92  October               0.0
# 197   Equatorial Guinea  1993/94  October               0.0
# 245               Benin  1994/95  October               0.0
# 301               Benin  1995/96  October               0.0
# 357               Benin  1996/97  October               0.0
# 413               Benin  1997/98  October               0.0
# 469               Benin  1998/99  October               0.0
# 525               Benin  1999/00  October               0.0
# 581               Benin  2000/01  October               0.0
# 589   Equatorial Guinea  2000/01  October               0.0
# 591               Gabon  2000/01  October               0.0
# 637               Benin  2001/02  October               0.0
# 645   Equatorial Guinea  2001/02  October               0.0
# 693               Benin  2002/03  October               0.0
# 701   Equatorial Guinea  2002/03  October               0.0
# 749               Benin  2003/04  October               0.0
# 757   Equatorial Guinea  2003/04  October               0.0
# 805               Benin  2004/05  October               0.0
# 813   Equatorial Guinea  2004/05  October               0.0
# 861               Benin  2005/06  October               0.0
# 869   Equatorial Guinea  2005/06  October               0.0
# 917               Benin  2006/07  October               0.0
# 925   Equatorial Guinea  2006/07  October               0.0
# 973               Benin  2007/08  October               0.0
# 981   Equatorial Guinea  2007/08  October               0.0
# 1029              Benin  2008/09  October               0.0
# 1037  Equatorial Guinea  2008/09  October               0.0
# 1085              Benin  2009/10  October               0.0
# 1093  Equatorial Guinea  2009/10  October               0.0
# 1141              Benin  2010/11  October               0.0
# 1149  Equatorial Guinea  2010/11  October               0.0
# 1197              Benin  2011/12  October               0.0
# 1205  Equatorial Guinea  2011/12  October               0.0
# 1253              Benin  2012/13  October               0.0
# 1261  Equatorial Guinea  2012/13  October               0.0
# 1309              Benin  2013/14  October               0.0
# 1317  Equatorial Guinea  2013/14  October               0.0
# 1365              Benin  2014/15  October               0.0
# 1373  Equatorial Guinea  2014/15  October               0.0
# 1421              Benin  2015/16  October               0.0
# 1429  Equatorial Guinea  2015/16  October               0.0
# 1477              Benin  2016/17  October               0.0
# 1485  Equatorial Guinea  2016/17  October               0.0
# 1533              Benin  2017/18  October               0.0
# 1541  Equatorial Guinea  2017/18  October               0.0
#
#       DOMESTIC_CONSUMPTION  EXPORTABLE_PRODUCTION  GROSS_OPENING_STOCKS
# 21                     0.0                    0.0                 0.000
# 77                     0.0                    0.0                 0.000
# 197                    0.0                    0.0                 2.000
# 245                    0.0                    0.0                 0.000
# 301                    0.0                    0.0                 0.000
# 357                    0.0                    0.0                 0.000
# 413                    0.0                    0.0                 0.000
# 469                    0.0                    0.0                 0.000
# 525                    0.0                    0.0                 0.000
# 581                    0.0                    0.0                 0.000
# 589                    0.0                    0.0                 0.000
# 591                    0.3                    0.0                 2.309
# 637                    0.0                    0.0                 0.000
# 645                    0.0                    0.0                 0.000
# 693                    0.0                    0.0                 0.000
# 701                    0.0                    0.0                 0.000
# 749                    0.0                    0.0                 0.000
# 757                    0.0                    0.0                 0.000
# 805                    0.0                    0.0                 0.000
# 813                    0.0                    0.0                 0.000
# 861                    0.0                    0.0                 0.000
# 869                    0.0                    0.0                 0.000
# 917                    0.0                    0.0                 0.000
# 925                    0.0                    0.0                 0.000
# 973                    0.0                    0.0                 0.000
# 981                    0.0                    0.0                 0.000
# 1029                   0.0                    0.0                 0.000
# 1037                   0.0                    0.0                 0.000
# 1085                   0.0                    0.0                 0.000
# 1093                   0.0                    0.0                 0.000
# 1141                   0.0                    0.0                 0.000
# 1149                   0.0                    0.0                 0.000
# 1197                   0.0                    0.0                 0.000
# 1205                   0.0                    0.0                 0.000
# 1253                   0.0                    0.0                 0.000
# 1261                   0.0                    0.0                 0.000
# 1309                   0.0                    0.0                 0.000
# 1317                   0.0                    0.0                 0.000
# 1365                   0.0                    0.0                 0.000
# 1373                   0.0                    0.0                 0.000
# 1421                   0.0                    0.0                 0.000
# 1429                   0.0                    0.0                 0.000
# 1477                   0.0                    0.0                 0.000
# 1485                   0.0                    0.0                 0.000
# 1533                   0.0                    0.0                 0.000
# 1541                   0.0                    0.0                 0.000

# %% [markdown]
# Appears to be a genuine data point so I will leave it as is

# %%
plt.figure(figsize=(15,4))
sns.distplot(df.TOTAL_PRODUCTION,bins = 100, kde = False)

# %%
plt.figure(figsize=(15,4))
sns.distplot(df[df.TOTAL_PRODUCTION <= 2000].TOTAL_PRODUCTION,bins = 50, kde = False)

# %% [markdown]
# Now looking to see what numerical values look correlated

# %%
sns.pairplot(df)

# %% [raw]
# Doesn't seem to be a huge amount to be gained from this
#
# Lets seem who the largest producers are and look at changes over time

# %%
df.groupby('COUNTRY').sum()
# Out:
#                             TOTAL_PRODUCTION  DOMESTIC_CONSUMPTION  \
# COUNTRY
# Angola                          1.272038e+03              715.0000
# Benin                           1.855000e+00                0.0000
# Bolivia                         3.618669e+03             1465.0000
# Brazil                          1.118452e+06           419545.0000
# Burundi                         9.950275e+03               52.8670
# Cameroon                        2.207199e+04             2235.8490
# Central African Republic        2.963393e+03              373.2400
# Colombia                        3.317384e+05            40215.5944
# Congo, Dem. Rep. of             1.672670e+04             5600.0000
# Congo, Rep. of                  1.085680e+02               83.3340
# Costa Rica                      5.704299e+04            10371.9200
# Cuba                            5.716217e+03             5964.1000
# Côte d'Ivoire                   7.462904e+04             6203.6690
# Dominican Republic              1.431254e+04             9946.7230
# Ecuador                         3.061763e+04             6055.0000
# El Salvador                     4.557261e+04             6362.0340
# Equatorial Guinea               1.955980e+02                0.0000
# Ethiopia                        1.339629e+05            69542.0000
# Gabon                           5.939497e+03             4849.8820
# Ghana                           1.161796e+03              162.1800
# Guatemala                       1.094606e+05             9060.0000
# Guinea                          7.695578e+03             1345.5000
# Guyana                          1.486246e+02              135.3840
# Haiti                           1.095105e+04             9320.0000
# Honduras                        9.891794e+04             7139.1780
# India                           1.250009e+05            38714.3370
# Indonesia                       2.354822e+05            72085.0000
# Jamaica                         8.563494e+02              293.4670
# Kenya                           2.766792e+04             1400.0000
# Lao, People's Dem. Rep. of      8.018439e+03             2316.0000
# Liberia                         2.334064e+02              134.0000
# Madagascar                      1.664539e+04             9046.7660
# Malawi                          1.339194e+03               37.0000
# Mexico                          1.223045e+05            48286.0000
# Nepal                           1.702390e+01                0.0000
# Nicaragua                       3.994325e+04             4565.0050
# Nigeria                         1.281722e+03             1099.0000
# Panama                          4.443833e+03             1914.6160
# Papua New Guinea                2.836934e+04               56.1400
# Paraguay                        9.856590e+02              545.0000
# Peru                            8.052786e+04             6200.0000
# Philippines                     1.432737e+04            40028.0000
# Rwanda                          8.709756e+03              699.0000
# Sierra Leone                    1.372674e+03              158.0000
# Sri Lanka                       1.156605e+03              901.6670
# Tanzania                        2.244461e+04             1086.7510
# Thailand                        2.676370e+04            17885.0000
# Timor-Leste                     9.096657e+02                3.9200
# Togo                            4.533994e+03             1217.4300
# Trinidad & Tobago               4.057342e+02              331.5000
# Uganda                          8.894559e+04             4242.9400
# Venezuela                       3.196335e+04            36992.8000
# Vietnam                         4.099792e+05            26765.4720
# Yemen                           3.098526e+03             1988.0000
# Zambia                          1.225607e+03               16.5320
# Zimbabwe                        2.184478e+03              135.2660
#
#                             EXPORTABLE_PRODUCTION  GROSS_OPENING_STOCKS
# COUNTRY
# Angola                                   575.1330             1215.0000
# Benin                                      1.8550                0.0000
# Bolivia                                 2153.6690              209.9000
# Brazil                                698907.3505           669576.6150
# Burundi                                 9897.4081             1410.4110
# Cameroon                               19836.1405             5266.3490
# Central African Republic                2590.1533              475.1560
# Colombia                              291522.8135            66759.9920
# Congo, Dem. Rep. of                    11126.6962              987.1580
# Congo, Rep. of                           864.4700               56.0000
# Costa Rica                             46671.0704             4362.8200
# Cuba                                    1321.4599             2264.0000
# Côte d'Ivoire                          68425.3731            29655.8590
# Dominican Republic                      4459.3019             5427.6970
# Ecuador                                24562.6261             3146.1700
# El Salvador                            39210.5765             4799.3700
# Equatorial Guinea                        195.5980               10.2000
# Ethiopia                               64420.9365            58668.0000
# Gabon                                   4007.6613             3621.7780
# Ghana                                    999.6163              356.7430
# Guatemala                             100400.6098             3089.1820
# Guinea                                  6350.0785              746.0010
# Guyana                                    20.6753                0.0000
# Haiti                                   1631.0517              369.2360
# Honduras                               91778.7625             4213.2670
# India                                  86286.6052            26630.0000
# Indonesia                             163397.1765            19613.3250
# Jamaica                                  562.8824              250.9840
# Kenya                                  26267.9171             5869.5230
# Lao, People's Dem. Rep. of              5702.4389               19.0000
# Liberia                                 1398.1064                0.0000
# Madagascar                              7608.6602             2530.0230
# Malawi                                  1302.1944              142.0000
# Mexico                                 74018.5392            16563.2500
# Nepal                                     17.0239                0.0000
# Nicaragua                              35378.2468             2399.6070
# Nigeria                                  188.4532                8.0000
# Panama                                  2529.2170              908.3200
# Papua New Guinea                       28313.1989             1611.9799
# Paraguay                                 681.8180             1055.0000
# Peru                                   74327.8603             3085.3110
# Philippines                             1064.4650            16345.0000
# Rwanda                                  8676.0899              428.0940
# Sierra Leone                            1214.6738              408.0000
# Sri Lanka                                254.9381              106.0000
# Tanzania                               21357.8564             2922.6696
# Thailand                               12736.9123             2430.8840
# Timor-Leste                              905.7457                0.0000
# Togo                                    4498.3812             2141.2920
# Trinidad & Tobago                         74.2342               14.0430
# Uganda                                 84702.6520            29540.7290
# Venezuela                               3464.8243             3817.5450
# Vietnam                               383213.7502            39014.0010
# Yemen                                   1110.5264               48.0000
# Zambia                                  1209.0746                2.0000
# Zimbabwe                                2049.2124              524.0370

# %%
fig = plt.figure(figsize = (15,10))
plt.xticks(rotation = 'vertical',fontsize=15)
plt.yticks(fontsize=15)
df_sorted = df.groupby('COUNTRY').sum().sort_values('TOTAL_PRODUCTION',ascending=False)
plt.plot(df_sorted.index,df_sorted.TOTAL_PRODUCTION,
         color='red',
         marker='o',
         linestyle='none',
         mec='black')
_ = plt.semilogy()
_ = plt.ylabel('Total Production (Thousands of bags of bags of Coffee(60kg)) ',fontsize=15)
_ = plt.grid(which='both',axis='y')


ax = fig.add_axes([0.65,0.65,0.2,0.2])
ax.bar(df_sorted.index,df_sorted.TOTAL_PRODUCTION)
ax.axes.xaxis.set_visible(False)
ax.axes.yaxis.set_visible(False)
_ = ax.text(x=2,y=1000000,s='Brazil',fontsize=15)

# %% [markdown]
# Appears coffee production is dominated by a few countries such as brazil, colombia and vietnam.
#
# Lets explore that a bit more

# %%
plt.figure(figsize = (15,5))
plt.xticks(rotation = 'vertical')
dfBrazil = df[df.COUNTRY == 'Brazil']
plt.plot(dfBrazil.YEAR,dfBrazil.TOTAL_PRODUCTION,
        linestyle='none',
        marker='o',
        mec='k',
        mfc='r')
plt.plot(dfBrazil.YEAR,dfBrazil.loc[:,'TOTAL_PRODUCTION'].rolling(3,0).mean(),
        color='black',
        linestyle=':')

_ = plt.grid()
_ = plt.ylabel('Total Production (Thousands \n of bags of bags of Coffee(60kg)) ',rotation = 90,fontsize=15)
_ = plt.xlabel('Time',fontsize=15)
_ = plt.xticks(fontsize=15)
_ = plt.yticks(fontsize=15)

# %%
df2 = df.groupby('COUNTRY').sum()
df3 = df2[df2.TOTAL_PRODUCTION >200000]
n = list(df3.index)
large = df[df.COUNTRY.isin(n)]

# %%
plt.figure(figsize = (15,7))
plt.xticks(rotation ='vertical')
sns.scatterplot(x = 'YEAR', y= 'TOTAL_PRODUCTION',
             data = large,
             hue ='COUNTRY',
             marker='o',
                **{'edgecolor':'k'}
               )

color= ['blue','orange','green','red']

for i,j in enumerate(['Brazil','Indonesia', 'Colombia','Vietnam']):
    df_temp = df[df.COUNTRY == j]
    plt.plot(df_temp.YEAR,df_temp.loc[:,'TOTAL_PRODUCTION'].rolling(3,0).mean(),
        color=color[i],
        linestyle=':')

_ = plt.ylabel('Total Production (Thousands \n of bags of bags of Coffee(60kg)) ',rotation = 90,fontsize=15)
_ = plt.xlabel('Year',fontsize=15)

# %%
x = (df2.loc['Brazil'].TOTAL_PRODUCTION / sum(df2.TOTAL_PRODUCTION))*100
print('Brazil has contributed {}% to total coffee production since 1992'.format(round(x,2)))
# Out:
# Brazil has contributed 32.76% to total coffee production since 1992

# %%
df2 = df.groupby('COUNTRY').sum()
df3 = df2.sort_values('TOTAL_PRODUCTION').iloc[0:10,:]
n = list(df3.index)
small = df[df.COUNTRY.isin(n)]

# %%
plt.figure(figsize = (15,10))
plt.xticks(rotation ='vertical')
colors = sns.color_palette('Set1',10)
sns.lineplot(x = 'YEAR', y= 'TOTAL_PRODUCTION',
             data = small,
             hue ='COUNTRY',
             palette= colors,
            mec='k',
             marker='o,
             size='COUNTRY'
            )

_ = plt.ylabel('Total Production (Thousands \n of bags of bags of Coffee(60kg)) ',rotation = 90,fontsize=15)
_ = plt.xlabel('Year',fontsize=15)

plt.legend(ncol=2)
